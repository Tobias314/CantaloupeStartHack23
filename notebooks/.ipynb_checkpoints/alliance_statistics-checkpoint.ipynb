# %%
# %load_ext autoreload
# %autoreload 2
from sys import path
path.append('../')

# %%
import re

import seaborn as sb
import numpy as np
import pandas as pd
from tqdm.auto import tqdm

# %%
from utils.loading import load_data
from utils.protocol_creation import summarize_alliance
from utils.ai_summary import create_chatgpt_prompt
from utils.parser import parse_event, find_all_patterns

# %%
data = load_data('../data')
# Out:
# /home/tobi/development/start_hack_2023/notebooks/../utils/loading.py:16: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   messages2 = pd.read_csv(path /'chat_messages_2_fixed.csv')

# %%
alliance_groups = [(a,g) for a,g in data.messages.groupby('alliance_id')]

# %%
rol = r'abc'
re.search(rol, 'xbcx')

# %%
alliance_id = '80328c28b8c2d119d352806e35b2317ebfc955f5903b95f362924ab2208c5886'
account_id = '9a19df7b4c6e0fdf9014ebbf6e08aadfc39e5fd66bb1190bc8f2c17848945920'
alliance_messages = data.messages[data.messages.alliance_id==alliance_id].copy()
alliance_actions = data.alliance_membership[data.alliance_membership.alliance_id==alliance_id].copy()
res = parse_event(alliance_messages, alliance_actions, account_id=account_id)
res
# Out:
# {'join_hate_kick_regex': (1, 112)}

# %%
result['80328c28b8c2d119d352806e35b2317ebfc955f5903b95f362924ab2208c5886']
# Out:
# {'9a19df7b4c6e0fdf9014ebbf6e08aadfc39e5fd66bb1190bc8f2c17848945920': {'join_hate_kick_regex': (1,
#    112)}}

# %%
import requests
r = requests.post(
    "https://api.deepai.org/api/summarization",
    data={
        'text': 'YOUR_TEXT_URL',
    },
    headers={'api-key': 'quickstart-QUdJIGlzIGNvbWluZy4uLi4K'}
)
print(r.json())
# Out:
# {'id': '588d92af-e961-4232-a2bc-2bd17e18f6f5', 'output': ''}

# %%
for k in result.keys():
    print(k)
# Out:
# 000f62f0f7c1c2802701586e2ce4def5cae0aba253a51f10eb43eea221a25065
# 009720e479c15e47170784090f20c92af813d8bbe5e513e83105ee8bacbe7b97
# 00b43c00d734733f4bb2d12b2a4652d4ff942efd8999ac863dda87464e3de9c1
# 00caa26f4b3ed63840feb37daa8e67e0f45c9a953fd5434b529c8b3ce5e1c6be
# 0127d5f0b90153db95f28bbe92563ecc140effbd0189458ec1a4ace2f25cb67f
# 012fbf29d39d27885ebce16dd7b0cd007c7c53f8efd9129cd2040943c78891ad
# 0133e6dc35a1ffe3b698a3d29ed6e4e241e781cc4059c4ff924eee5ee0584b9b
# 014d67363d43c614b348273d6ee0e9ca600e83ea8b9b364e98478c774094e0e7
# 01508748557eb0dc242d880ef6bea25af9353508e6ae11d8bf9089f4c401e01d
# 016901c6e525ee26aa1c7d5d726c13a172217cfbed3f4d97e6a46d4cf1e5d35a
# 01819e40d17fe6ec975a94f14c2a2917eefbddc3664a99bd60005e7edc59d1d0
# 0183b0a3dd288b75faaf6e95a0be03ee9723d937e00f71b812768f6ce8d56bbb
# 01abac8c7071a79550d69b85d30333ddbde18a2914b28c3e8c1e5e8e80299ba1
# 01bab23ecf219baf2cb8e313906a39fcb51726e9cc21db33c461508843f58d63
# ...

# %%
summarize_alliance(data, '00b43c00d734733f4bb2d12b2a4652d4ff942efd8999ac863dda87464e3de9c1')
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# User: 2373e68733c4df8b5400 | 0.0$/20.96$ | 2.71h 400.37h | 35.0lvl | since 688 days | risk mean 3.0
# User: 78a51dfc9fd25690c4ca | 0.0$/0.0$ | 1.29h 1143.65h | 44.0lvl | since 2396 days | risk mean 2.8
# /home/tobi/development/start_hack_2023/notebooks/../utils/protocol_creation.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alliance_messages['content'] = alliance_messages['filtered_message']
# /home/tobi/development/start_hack_2023/notebooks/../utils/protocol_creation.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
result = find_all_patterns(data)
# Out:
#   0%|          | 0/72371 [00:00<?, ?it/s]
# {'join_hate_kick_regex': (1, 11)}
# {'join_hate_kick_regex': (1, 10)}
# {'join_hate_kick_regex': (1, 8)}
# {'join_hate_kick_regex': (1, 8)}
# {'join_hate_kick_regex': (33, 114)}
# {'join_hate_kick_regex': (1, 26)}
# {'join_hate_kick_regex': (21, 202)}
# {'join_hate_kick_regex': (31, 189)}
# {'join_hate_kick_regex': (1, 8)}
# {'join_hate_kick_regex': (1, 8)}
# {'join_hate_kick_regex': (1, 8)}
# {'join_hate_kick_regex': (1, 18)}
# {'join_hate_kick_regex': (1, 8)}
# {'join_hate_kick_regex': (1, 10)}
# {'join_hate_kick_regex': (1, 19)}
# {'join_hate_kick_regex': (1, 15)}
# {'join_hate_kick_regex': (3, 12)}
# {'join_hate_kick_regex': (1, 13)}
# {'join_hate_kick_regex': (5, 15)}
# {'join_hate_kick_regex': (1, 29)}
# {'join_hate_kick_regex': (1, 8)}
# {'join_hate_kick_regex': (1, 12)}
# {'join_hate_kick_regex': (1, 13)}
# {'join_hate_kick_regex': (33, 40)}
# {'join_hate_kick_regex': (1, 20)}
# {'join_hate_kick_regex': (1, 18)}
# ...

# %%
alliance_messages.raw_messa
# Out:
#                                                account_id  \
# 10639   9a19df7b4c6e0fdf9014ebbf6e08aadfc39e5fd66bb119...
# 19293   9a19df7b4c6e0fdf9014ebbf6e08aadfc39e5fd66bb119...
# 32894   9a19df7b4c6e0fdf9014ebbf6e08aadfc39e5fd66bb119...
# 36216   9a19df7b4c6e0fdf9014ebbf6e08aadfc39e5fd66bb119...
# 71172   9a19df7b4c6e0fdf9014ebbf6e08aadfc39e5fd66bb119...
# 89482   9a19df7b4c6e0fdf9014ebbf6e08aadfc39e5fd66bb119...
# 110332  9a19df7b4c6e0fdf9014ebbf6e08aadfc39e5fd66bb119...
# 124685  9a19df7b4c6e0fdf9014ebbf6e08aadfc39e5fd66bb119...
# 136228  9a19df7b4c6e0fdf9014ebbf6e08aadfc39e5fd66bb119...
# 152360  9a19df7b4c6e0fdf9014ebbf6e08aadfc39e5fd66bb119...
# 175031  9a19df7b4c6e0fdf9014ebbf6e08aadfc39e5fd66bb119...
# 39388   9a19df7b4c6e0fdf9014ebbf6e08aadfc39e5fd66bb119...
# 55028   9a19df7b4c6e0fdf9014ebbf6e08aadfc39e5fd66bb119...
#
#                                               alliance_id  \
# 10639   c75273f92388abdcb44b53bec8774b63595daf1b655c53...
# ...

# %%
join_hate_kick_regex.find_all(res)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 join_hate_kick_regex.find_all(res)
#
# AttributeError: 're.Pattern' object has no attribute 'find_all'

# %%
res
# Out:
# '()(J)()()()()()()()()()'

# %%
alliance_actions.loc[np.array([True]),'event'] = 'L'
#alliance_actions['event']='J'
alliance_actions
# Out:
#                                               account_id  \
# 36551  9e7b94da80f068295f30094bc8b6e200d12fdec2598898...
#
#                                              alliance_id  \
# 36551  fffde93d85e9adac9e59945e2ea6eea7cccfe7c11a9a88...
#
#                              timestamp        date action  size  max_size  \
# 36551 2023-03-01 02:47:22.454000+00:00  2023-03-01   join    40        50
#
#       event
# 36551     L

# %%
res[1]
# Out:
#                                               account_id  \
# 36551  9e7b94da80f068295f30094bc8b6e200d12fdec2598898...
#
#                                              alliance_id  \
# 36551  fffde93d85e9adac9e59945e2ea6eea7cccfe7c11a9a88...
#
#                              timestamp        date action  size  max_size  \
# 36551 2023-03-01 02:47:22.454000+00:00  2023-03-01   join    40        50
#
#       event
# 36551

# %%
summarize_alliance(data,alliance_id).iloc[1].account_id
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# User: 9e7b94da80f068295f30 | 0.0$/0.0$ | 2.15h 92.8h | 29.0lvl | since 675 days | risk mean 1.0
# /home/tobi/development/start_hack_2023/notebooks/../utils/protocol_creation.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alliance_messages['content'] = alliance_messages['filtered_message']
# /home/tobi/development/start_hack_2023/notebooks/../utils/protocol_creation.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
summary = summarize_alliance(data)
# Out:
#   0%|          | 0/72371 [00:00<?, ?it/s]

# %%
summary
# Out:
# [                                               account_id  \
#  145673  3695a4fe1546b3a9879c14ddbfb509ad714dc6e9f37355...
#  12323   1ba3e45c1897aad9cd911bcd6226b1630b50b90c9cd8a2...
#
#                                                alliance_id  \
#  145673  00000709d10b0d23ece5003a93f0ccef17561d8834553c...
#  12323   00000709d10b0d23ece5003a93f0ccef17561d8834553c...
#
#                                timestamp        date raw_message  \
#  145673 2023-03-01 14:32:14.395000+00:00  2023-03-01      Nigger
#  12323  2023-03-01 16:13:45.895000+00:00  2023-03-01      nigger
#
#         filtered_message filtered filtered_content  risk  \
#  145673           ******      1.0       ['Nigger']   6.0
#  12323            ******      1.0       ['nigger']   6.0
#
#         filter_detected_language  ...  CHILD_GROOMING  PUBLIC_THREAT  \
#  145673                       en  ...            -1.0           -1.0
#  12323                        en  ...            -1.0           -1.0
#
# ...
